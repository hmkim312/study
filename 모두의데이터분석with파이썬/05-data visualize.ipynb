# %% [markdown]
# # 데이터 시각화

# %%
#hist 함수

# %%
import matplotlib.pyplot as plt

# %%
plt.hist([1,1,2,5,4,6,8,4,3,5])
plt.show()

# %%
# 주사위 시뮬레이션

# %%
import random
print(random.randint(1,6))
# Out:
# 4

# %%
import random
dice = []
for i in range(6) :
    dice.append(random.randint(1,45))
print(dice)
# Out:
# [16, 7, 23, 6, 36, 34]

# %%
import random
dice = []
for i in range(100) :
    dice.append(random.randint(1,6))
print(dice)
plt.hist(dice,bins = 6)
plt.show()
# Out:
# [5, 2, 1, 6, 1, 4, 2, 1, 6, 2, 1, 6, 4, 4, 1, 3, 5, 1, 5, 6, 4, 1, 4, 1, 4, 1, 6, 1, 2, 1, 6, 3, 6, 3, 5, 4, 3, 6, 2, 5, 1, 2, 2, 3, 4, 5, 5, 2, 2, 5, 4, 3, 6, 2, 3, 5, 1, 5, 4, 4, 5, 6, 5, 6, 2, 2, 1, 5, 4, 6, 4, 2, 3, 3, 5, 1, 2, 2, 4, 2, 4, 6, 5, 4, 5, 6, 3, 6, 6, 1, 3, 6, 2, 2, 4, 2, 3, 4, 2, 5]

# %%
# 기온데이터를 히스토그램으로 표현하기

# %%
import csv
import matplotlib.pyplot as plt
f = open("..\data\SeoulTemperature_1904~2019.csv")
data = csv.reader(f)
header = next(data)
result = []

for row in data :
    if row[-1] !='' :
        result.append(float(row[-1]))

plt.hist(result, bins = 100, color = "r")
plt.show()

# %%
import csv
import matplotlib.pyplot as plt
f = open("..\data\SeoulTemperature_1904~2019.csv")
data = csv.reader(f)
header = next(data)
aug = []

for row in data :
    month = row[0].split('-')[1]
    if row[-1] !='' :
        if month =="08" :
         aug.append(float(row[-1]))

plt.hist(aug, bins = 100, color = "r")
plt.show()

# %%
import csv
import matplotlib.pyplot as plt

f = open("..\data\SeoulTemperature_1904~2019.csv")
data = csv.reader(f)
header = next(data)

aug = []
jan = []

for row in data :
    month = row[0].split('-')[1]
    if row[-1] != '' :
        if month == '08' : 
            aug.append(float(row[-1]))
        if month == '01' :
            jan.append(float(row[-1]))
        
plt.hist(aug, bins = 100, color = "r", label = "Aug")
plt.hist(jan, bins = 100, color = "b", label = "Jan")
plt.legend()
plt.show()

# %%
# 기온데이터를 상자 그림으로 표현하기

# %%
import matplotlib.pyplot as plt
import random
import numpy as np
result = []

for i in range(13) :
    result.append(random.randint(1,1000))
result = np.array(result)
print("1/4: " + str(np.percentile(result,25)))
print("2/4: " + str(np.percentile(result,50)))
print("3/4: " + str(np.percentile(result,75)))
print(sorted(result))

plt.boxplot(result)
plt.show()
# Out:
# 1/4: 234.0
# 2/4: 506.0
# 3/4: 843.0
# [30, 45, 205, 234, 302, 363, 506, 792, 793, 843, 877, 888, 916]

# %%
import csv
import matplotlib.pyplot as plt

f = open("..\data\SeoulTemperature_1904~2019.csv")
data = csv.reader(f)
header = next(data)
result = []

for row in data : 
    if row[-1] !='' :
        result.append(float(row[-1]))
        
plt.boxplot(result)
plt.show()

# %%
import csv
import matplotlib.pyplot as plt

f = open("..\data\SeoulTemperature_1904~2019.csv")
data = csv.reader(f)
header = next(data)
aug = []
jan = []

for row in data :
    month = row[0].split("-")[1]
    if row[-1] !='' :
        if month == "08" :
            aug.append(float(row[-1]))
        if month == "01" :
            jan.append(float(row[-1]))

plt.boxplot(aug)
plt.boxplot(jan)
plt.show()

# %%
import csv
import matplotlib.pyplot as plt

f = open("..\data\SeoulTemperature_1904~2019.csv")
data = csv.reader(f)
header = next(data)
aug = []
jan = []

for row in data :
    month = row[0].split("-")[1]
    if row[-1] !='' :
        if month == "08" :
            aug.append(float(row[-1]))
        if month == "01" :
            jan.append(float(row[-1]))

plt.boxplot([aug,jan])
plt.show()

# %%
import csv
import matplotlib.pyplot as plt

f = open("..\data\SeoulTemperature_1904~2019.csv")
data = csv.reader(f)
header = next(data)
month = [[],[],[],[],[],[],[],[],[],[],[],[]]


for row in data :
    if row[-1] !='' :
        # 월과 같은 번호의 인덱스에 월별 데이터 저장
        month[int(row[0].split('-')[1])-1].append(float(row[-1]))

plt.boxplot(month)
plt.show()

# %% [markdown]
# # 8월 일별 기온 데이터를 상자 그림으로 표현하기

# %%
import matplotlib.pyplot as plt
import csv

f = open("..\data\SeoulTemperature_1904~2019.csv")
data = csv.reader(f)
header = next(data)

day = [] #일별 데이터를 저장할 리스트 day 생성
for i in range(31) :
    day.append([]) # day 리스트 내 31개 리스트 생성
    
for row in data :
    if row[-1] !="" :
        if row[0].split("-")[1] == "08" : # 8월이라면
            # 최고 기온 값 저장
            day[int(row[0].split("-")[2])-1].append(float(row[-1]))

plt.style.use('ggplot') # 그래프 스타일 지정
plt.figure(figsize = (10,5), dpi = 300) # 그래프 크기 수정
plt.boxplot(day, showfliers = False) # 아웃라이어 값 생략

plt.show()
